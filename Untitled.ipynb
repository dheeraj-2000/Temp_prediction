# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/home/dheeraj/my_projects/my_project_env/practice/EDA_and_prediction/sku.csv')
df.head()
# Out:
#     SKU  01/08/2019  02/08/2019  03/08/2019  04/08/2019  05/08/2019  \
# 0  2527        1551        1613        1613        1532        1517
# 1  3042        2240        2330        2423        2350        2374
# 2  3086         891         909         936         889         880
# 3  3155        1628        1628        1563        1532        1563
# 4  3166         369         354         343         340         330
#
#    06/08/2019  07/08/2019  08/08/2019  09/08/2019  ...  22/07/2020  \
# 0        1441        1383        1424        1381  ...        1929
# 1        2398        2278        2210        2232  ...        7096
# 2         906         870         879         844  ...         829
# 3        1563        1532        1593        1513  ...        1719
# 4         337         350         343         340  ...         335
#
#    23/07/2020  24/07/2020  25/07/2020  26/07/2020  27/07/2020  28/07/2020  \
# 0        1948        1929        1987        2027        1926        1926
# 1        7025        6955        6746        6881        6606        6804
# 2         829         812         788         788         772         811
# 3        1805        1895        1895        1990        2030        2050
# 4         328         325         319         316         319         329
#
#    29/07/2020  30/07/2020  31/07/2020
# 0        1849        1904        1828
# 1        6872        6872        7078
# 2         803         763         763
# 3        2132        2111        2027
# 4         336         349         352
#
# [5 rows x 367 columns]

# %%
df.iloc[2:3, 1:32]
# Out:
#    01/08/2019  02/08/2019  03/08/2019  04/08/2019  05/08/2019  06/08/2019  \
# 2         891         909         936         889         880         906
#
#    07/08/2019  08/08/2019  09/08/2019  10/08/2019  ...  22/08/2019  \
# 2         870         879         844         852  ...         892
#
#    23/08/2019  24/08/2019  25/08/2019  26/08/2019  27/08/2019  28/08/2019  \
# 2         901         883         865         865         874         900
#
#    29/08/2019  30/08/2019  31/08/2019
# 2         927         890         854
#
# [1 rows x 31 columns]

# %%
aug = df.iloc[0:, 1:32].mean().mean()
aug
# Out:
# 2166.671542379522

# %%
sep = df.iloc[0:, 32:62].mean().mean()
sep
# Out:
# 2335.942105263158

# %%
octu = df.iloc[0:, 62:93].mean().mean()
octu
# Out:
# 2389.984066866919

# %%
nov = df.iloc[0:, 93:123].mean().mean()
nov
# Out:
# 2422.9439946018892

# %%
dec = df.iloc[0:, 123:154].mean().mean()
dec
# Out:
# 2551.4261460101866

# %%
jan = df.iloc[0:, 154:185].mean().mean()
jan
# Out:
# 2503.6044142614605

# %%
feb = df.iloc[0:, 185:214].mean().mean()
feb
# Out:
# 2509.208013402206

# %%
march = df.iloc[0:, 214:245].mean().mean()
march
# Out:
# 2642.623742980279

# %%
april= df.iloc[0:, 245:275].mean().mean()
april
# Out:
# 2578.066396761133

# %%
may= df.iloc[0:, 275:306].mean().mean()
may
# Out:
# 2423.3964999347

# %%
june= df.iloc[0:, 306:336].mean().mean()
june
# Out:
# 2470.1121457489876

# %%
july= df.iloc[0:, 336:367].mean().mean()
july
# Out:
# 2454.717382786993

# %%
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 32:62])
    l.append(df.iloc[index, 62:93])
    l.append(df.iloc[index, 93:123])
    
    l.append(df.iloc[index, 123::32])
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 1:32])
    l.append(df.iloc[index, 1:32])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input
#  126.77419354838709,
#  9.0,
#  4.0,
#  3.0,
#  133.4516129032258,
#  32.774193548387096,
#  48.387096774193544,
#  13.193548387096774,
#  8.0,
#  36.38709677419355,
#  33.61290322580645,
#  77.06451612903227,
#  2.0,
#  6.0,
#  1084.2903225806454,
#  519.516129032258,
#  21.935483870967737,
#  78.45161290322581,
#  62.967741935483865,
#  56.032258064516135,
#  190.90322580645162,
#  405.77419354838713,
#  49.32258064516129,
#  5.0,
#  121.41935483870968,
#  42.32258064516129,
#  1.0,
#  2.0,
#  18.451612903225808,
#  6.0,
#  1.0,
#  1.0,
#  3.0,
#  5.0,
#  26.451612903225808,
#  10.516129032258064,
#  2.0,
#  10.35483870967742,
#  2.0,
#  82.48387096774194,
#  1057.516129032258,
#  3726.193548387097,
#  4494.0,
#  1902.4193548387095,
#  1340.548387096774,
#  1913.8709677419354,
#  226.54838709677418,
#  76.51612903225806,
#  836.4193548387095,
#  59.67741935483871,
#  23.41935483870968,
#  2.0,
#  16.06451612903226,
#  22.225806451612907,
#  16.258064516129032,
#  13.870967741935484,
#  60.41935483870968,
#  46.354838709677416,
#  49.806451612903224,
#  10.93548387096774,
#  5.0,
#  3.0,
#  20.548387096774192,
#  29.064516129032263,
#  2.0,
#  54.903225806451616,
#  105.77419354838709,
#  2.0,
#  147.77419354838707,
#  96.22580645161291,
#  125.32258064516131,
#  193.5161290322581,
#  137.58064516129033,
#  47.161290322580655,
#  11.419354838709678,
#  1182.967741935484,
#  9.0,
#  112.77419354838709,
#  49.516129032258064,
#  48.612903225806456,
#  16.0,
#  55.774193548387096,
#  32.90322580645161,
#  60.0,
#  27.87096774193548,
#  13.67741935483871,
#  14.258064516129034,
#  8.0,
#  3.0,
#  6.0,
#  3.0,
#  49.58064516129032,
#  971.032258064516,
#  2353.5806451612907,
#  1330.548387096774,
#  3271.7419354838707,
#  1324.8064516129034,
#  913.3870967741935,
#  12.096774193548386,
#  552.483870967742,
#  9.0,
#  10.0,
#  8.0,
#  14.709677419354836,
#  4.0,
#  5.0,
#  2.0,
#  228.29032258064515,
#  113.83870967741936,
#  184.03225806451616,
#  38.25806451612903,
#  182.67741935483872,
#  186.5161290322581,
#  130.48387096774192,
#  127.93548387096773,
#  61.58064516129032,
#  25.064516129032263,
#  55.74193548387096,
#  27.41935483870968,
#  16.387096774193548,
#  144.19354838709674,
#  1015.2903225806452,
#  242.74193548387098,
#  473.0322580645162,
#  1382.774193548387,
#  7544.870967741936,
#  5462.8064516129025,
#  813.2258064516128,
#  800.3548387096774,
#  350.09677419354836,
#  22.096774193548388,
#  26.516129032258068,
#  29.838709677419356,
#  15.419354838709678,
#  77.25806451612904,
#  101.64516129032258,
#  2.0,
#  22.0,
#  10.419354838709678,
#  93.09677419354837,
#  2.0]

# %%
outliers=[]
def detect_outlier(data_1):
    
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
outlier_datapoints = detect_outlier(out)
print(outlier_datapoints)
# Out:
# [33208.16129032258, 25064.0, 24930.0, 89585.70967741935, 26285.870967741932]

# %%
def getIndexes(dfObj, value):
    ''' Get index positions of value in dataframe i.e. dfObj.'''
    listOfPos = list()
    # Get bool dataframe with True at positions where the given value exists
    result = dfObj.isin([value])
    # Get list of columns that contains the value
    seriesObj = result.any()
    columnNames = list(seriesObj[seriesObj == True].index)
    listOfPos.append(columnNames)
    # Iterate over list of columns and fetch the rows indexes where value exists
#     for col in columnNames:
#         rows = list(result[col][result[col] == True].index)
#         for row in rows:
#             listOfPos.append((row, col))
    # Return a list of tuples indicating the positions of value in the dataframe
    return listOfPos

# %%
# # # out.item()
# for i in range(11):
#     print(i)

# %%
for i in outlier_datapoints:
    listOfPositions = getIndexes(month, i)
# print('Index positions of 81 in Dataframe : ')
    for i in range(len(listOfPositions)):
        print('Position ', i, ' (Row index , Column Name) : ', listOfPositions[i])
# Out:
# Position  0  (Row index , Column Name) :  ['38320']
# Position  0  (Row index , Column Name) :  ['65001']
# Position  0  (Row index , Column Name) :  ['65202']

# %%
for l in range(12):
    out1 = month.iloc[l,:].to_list()

    ########################### Finding outlier
    outliers=[]
    def detect_outlier(data_1):
    
        threshold=3
        mean_1 = np.mean(data_1)
        std_1 =np.std(data_1)
    
    
        for y in data_1:
            z_score= (y - mean_1)/std_1 
            if np.abs(z_score) > threshold:
                outliers.append(y)
        return outliers

    outlier_datapoints = detect_outlier(out1)
    print(outlier_datapoints)

    ############################ Finding index

    def getIndexes(dfObj, value):
        listOfPos = list()
        result = dfObj.isin([value])
        seriesObj = result.any()
        columnNames = list(seriesObj[seriesObj == True].index)
        listOfPos.append(columnNames)
        return listOfPos


    for i in outlier_datapoints:
        listOfPositions = getIndexes(month, i)
        for i in range(len(listOfPositions)):
            print(listOfPositions[i])
# Out:
# [33208.16129032258, 25064.0, 24930.0, 89585.70967741935, 26285.870967741932]
# ['14119']
# ['38194']
# ['38320']
# ['65001']
# ['65202']
# [40450.13333333333, 112037.73333333334, 31765.4]
# ['14119']
# ['65001']
# ['65202']
# [41428.48387096774, 31085.516129032258, 127952.93548387096, 36106.354838709674]
# ['14119']
# ['38194']
# ['65001']
# ['65202']
# [33638.73333333333, 126434.3, 49790.16666666666]
# ['14119']
# ['65001']
# ['65202']
# [151083.2258064516, 38985.096774193546]
# ['65001']
# ['65202']
# [155178.19354838712]
# ['65001']
# [173176.7931034483]
# ['65001']
# [48968.548387096766, 194893.64516129036]
# ['38320']
# ['65001']
# [64069.43333333333, 156093.96666666667, 37755.333333333336]
# ['38320']
# ['65001']
# ['65202']
# [32950.096774193546, 69276.3870967742, 122446.19354838708, 42331.6129032258]
# ['14119']
# ['38320']
# ['65001']
# ['65202']
# [35086.4, 65111.63333333332, 118284.06666666668, 54040.53333333333]
# ['14119']
# ['38320']
# ['65001']
# ['65202']
# [63582.45161290322, 116779.41935483873, 57243.3870967742]
# ['38320']
# ['65001']
# ['65202']
